# %% [markdown]
# # Détection d’objets avec YOLOv5
# Ce notebook présente une démonstration de la détection d’objets en utilisant YOLOv5.

# %%
# Cloner le dépôt officiel YOLOv5
# !git clone https://github.com/ultralytics/yolov5

# Accéder au dossier
# %cd yolov5

# Installer les dépendances
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17802, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 17802 (delta 7), reused 4 (delta 4), pack-reused 17788 (from 2)
# Receiving objects: 100% (17802/17802), 17.00 MiB | 19.23 MiB/s, done.
# Resolving deltas: 100% (12137/12137), done.
# /content/yolov5/yolov5
# ...

# %%
# Détection d'objets sur une image exemple
# !python detect.py --weights yolov5s.pt --source https://ultralytics.com/images/bus.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=https://ultralytics.com/images/bus.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# ...
# 100% 134k/134k [00:00<00:00, 6.69MB/s]
# YOLOv5 🚀 v7.0-459-gdd2e2574 Python-3.12.12 torch-2.9.0+cpu CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 141MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/yolov5/yolov5/bus.jpg: 640x480 4 persons, 1 bus, 344.5ms
# Speed: 2.5ms pre-process, 344.5ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Charger l’image résultat
img = Image.open("runs/detect/exp/bus.jpg")

plt.figure(figsize=(10,6))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# Exemple : détecter des objets dans une image uploadée
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/Images/test.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/Images/test.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-459-gdd2e2574 Python-3.12.12 torch-2.9.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Traceback (most recent call last):
#   File "/content/yolov5/yolov5/detect.py", line 436, in <module>
#     main(opt)
#   File "/content/yolov5/yolov5/detect.py", line 431, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 120, in decorate_context
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !ls /content/drive/MyDrive/IMAGE/
# Out:
# IMAGE1.jpg  IMAGE3.jpg	 IMAGE5.avif  IMAGE7.webp
# IMAGE2.jpg  IMAGE4.jpeg  IMAGE6.jpg   IMAGE8.jpg

# %%
# !python detect.py --weights yolov5s.pt --source /content/drive/MyDrive/IMAGE/IMAGE6.jpg
# Out:
# detect: weights=['yolov5s.pt'], source=/content/drive/MyDrive/IMAGE/IMAGE6.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-459-gdd2e2574 Python-3.12.12 torch-2.9.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/drive/MyDrive/IMAGE/IMAGE6.jpg: 384x640 3 persons, 3 cars, 2 traffic lights, 1 umbrella, 1 handbag, 431.1ms
# Speed: 2.1ms pre-process, 431.1ms inference, 3.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !ls runs/detect/
# Out:
# exp  exp2  exp3  exp4

# %%
# !ls runs/detect/exp2/

# %%
# !ls runs/detect/exp/
# Out:
# bus.jpg

# %%
# !ls runs/detect/exp3/
# Out:
# IMAGE6.jpg

# %%
import matplotlib.pyplot as plt
from PIL import Image

result = Image.open("runs/detect/exp3/IMAGE6.jpg")

plt.figure(figsize=(10,6))
plt.imshow(result)
plt.axis("off")
plt.show()
